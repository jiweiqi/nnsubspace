# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import numpy as np

from nnsubspace.nnsubspace.subspace import NNSubspace
from nnsubspace.nndataset.dataset import Dataset
from nnsubspace.nnmodel.model import NNModel
import nnsubspace.visual.subspaceplot as subspaceplot
# Out:
# C:\Anaconda3\lib\site-packages\h5py\__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
dataset_name = 'cifar10'

dataset_ = Dataset(dataset=dataset_name)
model_ = NNModel(dataset=dataset_name, model_id='0')
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples

# %%
for i_sample, x in enumerate(dataset_.x_test[0:5000]):
    x = np.expand_dims(x, axis=0)
    y = model_.model.predict(x)
    if y.max() < 0.6:
        print('sample {}'.format(i_sample))
        dataset_.decode_predictions(y)
        dataset_.decode_predictions(dataset_.y_test[i_sample])

        # x = dataset_.x_test[356]
        # x = np.expand_dims(x, axis=0)
        # y = model_.model.predict(x)
        # dataset_.decode_predictions(y)

        subspaceplot.imshow(np.squeeze(x + dataset_.x_train_mean), figsize=(2, 2))

        AS = NNSubspace(model=model_.model, x=x, x_train_mean=dataset_.x_train_mean)

        AS.sampling_setup(num_gradient_mc=300,
                          num_rs_mc=50000,
                          seed=7,
                          bool_clip=True,
                          sigma=10 / 255,
                          num_eigenvalue=20)
        AS.run()
# Out:
# sample 57
# label: dog, score: 0.58
# label: horse, score: 1.00
# @sampling
# A Jupyter Widget
# @evaluate_gradient
# A Jupyter Widget
# 300/300 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 3s 9ms/step
# @svd
# sample 58
# label: dog, score: 0.53
# label: deer, score: 1.00
# @sampling
# A Jupyter Widget
# @evaluate_gradient
# A Jupyter Widget
# 300/300 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 3s 10ms/step
# @svd
# sample 68
# label: cat, score: 0.53
# label: cat, score: 1.00
# @sampling
# A Jupyter Widget
# @evaluate_gradient
# A Jupyter Widget
# 300/300 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 3s 9ms/step
# @svd
# sample 112
# label: bird, score: 0.47
# label: frog, score: 1.00
# @sampling
# A Jupyter Widget
# @evaluate_gradient
# A Jupyter Widget
# 300/300 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 3s 9ms/step
# @svd
# sample 147
# label: dog, score: 0.51
# label: bird, score: 1.00
# @sampling
# A Jupyter Widget
# @evaluate_gradient
# A Jupyter Widget
# 300/300 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 4s 14ms/step
# @svd
# sample 169
# label: plane, score: 0.55
# label: plane, score: 1.00
# @sampling
# A Jupyter Widget
# @evaluate_gradient
# A Jupyter Widget
# 300/300 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 4s 12ms/step
# @svd
# sample 211
# label: horse, score: 0.51
# label: deer, score: 1.00
# @sampling
# A Jupyter Widget
# @evaluate_gradient
# A Jupyter Widget
# 300/300 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 3s 11ms/step
# @svd
# sample 221
# label: frog, score: 0.58
# label: frog, score: 1.00
# @sampling
# A Jupyter Widget
# @evaluate_gradient
# A Jupyter Widget
# 300/300 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 3s 10ms/step
# @svd
# sample 223
# label: deer, score: 0.58
# label: deer, score: 1.00
# @sampling
# A Jupyter Widget
# @evaluate_gradient
# A Jupyter Widget
# 300/300 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 3s 9ms/step
# @svd
# sample 226
# label: frog, score: 0.60
# label: frog, score: 1.00
# @sampling
# A Jupyter Widget
# @evaluate_gradient
# A Jupyter Widget
# 300/300 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 3s 10ms/step
# @svd
# sample 232
# label: dog, score: 0.53
# label: dog, score: 1.00
# @sampling
# A Jupyter Widget
# @evaluate_gradient
# A Jupyter Widget
# 300/300 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 3s 10ms/step
# @svd
# sample 266
# label: cat, score: 0.54
# label: bird, score: 1.00
# @sampling
# A Jupyter Widget
# @evaluate_gradient
# A Jupyter Widget
# 300/300 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 3s 10ms/step
# @svd
# sample 275
# label: dog, score: 0.56
# label: dog, score: 1.00
# @sampling
# A Jupyter Widget
# @evaluate_gradient
# A Jupyter Widget
# 300/300 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 3s 10ms/step
# @svd
# sample 281
# label: car, score: 0.52
# label: plane, score: 1.00
# @sampling
# A Jupyter Widget
# @evaluate_gradient
# A Jupyter Widget
# 300/300 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 3s 11ms/step
# @svd
# sample 287
# label: deer, score: 0.45
# label: plane, score: 1.00
# @sampling
# A Jupyter Widget
# @evaluate_gradient
# A Jupyter Widget
# 300/300 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 3s 9ms/step
# @svd
# sample 308
# label: truck, score: 0.59
# label: car, score: 1.00
# @sampling
# A Jupyter Widget
# @evaluate_gradient
# A Jupyter Widget
# 300/300 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 3s 10ms/step
# @svd
# sample 323
# label: deer, score: 0.56
# label: cat, score: 1.00
# @sampling
# A Jupyter Widget
# @evaluate_gradient
# A Jupyter Widget
# 300/300 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 3s 9ms/step
# @svd
# sample 356
# label: cat, score: 0.33
# label: cat, score: 1.00
# @sampling
# A Jupyter Widget
# @evaluate_gradient
# A Jupyter Widget
# 300/300 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 3s 9ms/step
# @svd
# sample 405
# label: bird, score: 0.53
# label: deer, score: 1.00
# @sampling
# A Jupyter Widget
# @evaluate_gradient
# A Jupyter Widget
# 300/300 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 3s 10ms/step
# @svd
# sample 436
# label: bird, score: 0.57
# label: bird, score: 1.00
# @sampling
# A Jupyter Widget
# @evaluate_gradient
# A Jupyter Widget
# 300/300 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 3s 9ms/step
# @svd
# sample 456
# label: cat, score: 0.53
# label: cat, score: 1.00
# @sampling
# A Jupyter Widget
# @evaluate_gradient
# A Jupyter Widget
# 300/300 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 3s 9ms/step
# @svd
# sample 562
# label: cat, score: 0.58
# label: frog, score: 1.00
# @sampling
# A Jupyter Widget
# @evaluate_gradient
# A Jupyter Widget
# 300/300 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 3s 10ms/step
# @svd
# sample 598
# label: deer, score: 0.48
# label: dog, score: 1.00
# @sampling
# A Jupyter Widget
# @evaluate_gradient
# A Jupyter Widget
# 300/300 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 3s 10ms/step
# @svd
# sample 685
# label: cat, score: 0.60
# label: frog, score: 1.00
# @sampling
# A Jupyter Widget
# @evaluate_gradient
# A Jupyter Widget
# 300/300 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 3s 10ms/step
# @svd
# sample 799
# label: bird, score: 0.52
# label: bird, score: 1.00
# @sampling
# A Jupyter Widget
# @evaluate_gradient
# A Jupyter Widget
# 300/300 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 3s 11ms/step
# @svd
# sample 810
# label: cat, score: 0.58
# label: dog, score: 1.00
# @sampling
# A Jupyter Widget
# @evaluate_gradient
# A Jupyter Widget
# 300/300 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 3s 9ms/step
# @svd
# sample 878
# label: cat, score: 0.51
# label: cat, score: 1.00
# @sampling
# A Jupyter Widget
# @evaluate_gradient
# A Jupyter Widget
# 300/300 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 3s 10ms/step
# @svd
# sample 889
# label: frog, score: 0.59
# label: deer, score: 1.00
# @sampling
# A Jupyter Widget
# @evaluate_gradient
# A Jupyter Widget
# 300/300 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 3s 10ms/step
# @svd
# sample 972
# label: frog, score: 0.49
# label: bird, score: 1.00
# @sampling
# A Jupyter Widget
# @evaluate_gradient
# A Jupyter Widget
# 300/300 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 3s 10ms/step
# @svd
# sample 982
# label: horse, score: 0.57
# label: plane, score: 1.00
# @sampling
# A Jupyter Widget
# @evaluate_gradient
# A Jupyter Widget
# 300/300 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 3s 9ms/step
# @svd
# sample 1034
# label: deer, score: 0.44
# label: frog, score: 1.00
# @sampling
# A Jupyter Widget
# @evaluate_gradient
# A Jupyter Widget
# 300/300 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 3s 10ms/step
# @svd
# sample 1050
# label: cat, score: 0.54
# label: cat, score: 1.00
# @sampling
# A Jupyter Widget
# @evaluate_gradient
# A Jupyter Widget
# 300/300 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 3s 10ms/step
# @svd
# sample 1138
# label: cat, score: 0.47
# label: dog, score: 1.00
# @sampling
# A Jupyter Widget
# @evaluate_gradient
# A Jupyter Widget
# 300/300 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 3s 10ms/step
# @svd
# sample 1150
# label: cat, score: 0.42
# label: bird, score: 1.00
# @sampling
# A Jupyter Widget
# @evaluate_gradient
# A Jupyter Widget
# 300/300 [==============================] - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - ETA:  - 3s 10ms/step
# @svd
# sample 1166
# label: dog, score: 0.58
# label: cat, score: 1.00
# @sampling
# A Jupyter Widget
# @evaluate_gradient
# A Jupyter Widget
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-4534bc369547> in <module>()
#      22                           sigma=10 / 255,
#      23                           num_eigenvalue=20)
# ---> 24         AS.run()
#
# D:\NextCloud\NNSubspace\nnsubspace\nnsubspace\nnsubspace\subspace.py in run(self)
#      50         self.sampling()
#      51         self.get_i_class()
# ---> 52         self.evaluate_gradient()
#      53         self.evaluate_sample()
#      54         self.svd()
#
# D:\NextCloud\NNSubspace\nnsubspace\nnsubspace\nnsubspace\subspace.py in evaluate_gradient(self)
#     144         for count, sample in tqdm(enumerate(self.x_samples_gradient)):
#     145             evaluated_gradients = self.tf_session.run(self.gradients,
# --> 146                                                       feed_dict={self.model.input: np.expand_dims(sample, axis=0)})
#     147             self.samples_gradient[count] = evaluated_gradients[0][0]
#     148
#
# C:\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     927     try:
#     928       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 929                          run_metadata_ptr)
#     930       if run_metadata:
#     931         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# C:\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1150     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1151       results = self._do_run(handle, final_targets, final_fetches,
# -> 1152                              feed_dict_tensor, options, run_metadata)
#    1153     else:
#    1154       results = []
#
# C:\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1326     if handle is None:
#    1327       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1328                            run_metadata)
#    1329     else:
#    1330       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# C:\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1332   def _do_call(self, fn, *args):
#    1333     try:
# -> 1334       return fn(*args)
#    1335     except errors.OpError as e:
#    1336       message = compat.as_text(e.message)
#
# C:\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1317       self._extend_graph()
#    1318       return self._call_tf_sessionrun(
# -> 1319           options, feed_dict, fetch_list, target_list, run_metadata)
#    1320
#    1321     def _prun_fn(handle, feed_dict, fetch_list):
#
# C:\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1405     return tf_session.TF_SessionRun_wrapper(
#    1406         self._session, options, feed_dict, fetch_list, target_list,
# -> 1407         run_metadata)
#    1408
#    1409   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
